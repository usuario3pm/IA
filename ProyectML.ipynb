# %% [markdown]
# <a href="https://colab.research.google.com/github/usuario3pm/IA/blob/main/ProyectML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recursos y librerias

# %%
# Recursos
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import torch
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
from sklearn.tree import plot_tree
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import warnings
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
warnings.filterwarnings('ignore')

# %% [markdown]
# # Funciones

# %%
#Calculo errores
def Error(y_real, y_pred):
    """
    Calcula métricas de error comunes para evaluar el modelos de predicción.

    Parámetros:
    - y_real: array-like, valores reales (observados).
    - y_pred: array-like, valores predichos por el modelo.

    Retorna:
    - métricas:  MAE, MAPE, MSE, RMSE, R2 y EVR.
    """
    # Convertir a arrays de NumPy
    y_real = np.array(y_real, dtype=np.float64)
    y_pred = np.array(y_pred, dtype=np.float64)

    # Validación de dimensiones
    if y_real.shape != y_pred.shape:
        raise ValueError("Las dimensiones de y_real y y_pred no coinciden.")

    # MAE (Error absoluto medio)
    mae = np.mean(np.abs(y_real - y_pred))

    # MAPE (Error porcentual absoluto medio)
    mape = np.mean(np.abs((y_real - y_pred) / y_real)) * 100

    # MSE (Error cuadrático medio)
    mse = np.mean((y_real - y_pred) ** 2)

    # RMSE (Raíz del error cuadrático medio)
    rmse = np.sqrt(mse)

    # R2 (Coeficiente de determinación)
    ss_total = np.sum((y_real - np.mean(y_real)) ** 2)
    ss_residual = np.sum((y_real - y_pred) ** 2)
    r2 = 1 - (ss_residual / ss_total)

    # EVR (Varianza explicada)
    var_real = np.var(y_real)
    var_error = np.var(y_real - y_pred)
    evr = 1 - (var_error / var_real)

    # Retornar métricas
    return mae,mape, mse,rmse, r2, evr

# encoder manual
def encode_activities_manual(train_df, test_df, activity_cols):
    # valores únicos
    all_activities = set(['missing'])  # Incluye un valor para manejar los nulos
    for col in activity_cols:
        all_activities.update(train_df[col].dropna().unique())  # Valores únicos en train_df
        if test_df is not None:
            all_activities.update(test_df[col].dropna().unique())  # Valores únicos en test_df

    #  mapeo entre actividades y INT
    activity_mapping = {activity: idx for idx, activity in enumerate(sorted(all_activities))}
    print(activity_mapping)

    #  Reemplazar valores categóricos por INT en train_df
    for col in activity_cols:
        train_df[col] = train_df[col].fillna('missing')  # Rellenar valores faltantes
        train_df[col] = train_df[col].map(activity_mapping)  # Mapear valores al mapeo creado

        if test_df is not None:
            #Reemplazar valores categóricos por enteros en test_df
            test_df[col] = test_df[col].fillna('missing')  # Rellenar valores faltantes
            test_df[col] = test_df[col].map(activity_mapping)  # Mapear valores al mapeo creado

    return train_df, test_df

def process_time(df):
    df['time'] = pd.to_datetime(df['time'])
    df['hour'] = df['time'].dt.hour
    df['minute'] = df['time'].dt.minute
    df['second'] = df['time'].dt.second
    return df

def encoder_actividades(train_df, test_df, activity_cols):
    le = LabelEncoder()
    all_activities = ['missing']
    for col in activity_cols:
        all_activities.extend(train_df[col].dropna().unique())
        if test_df is not None:
            all_activities.extend(test_df[col].dropna().unique())

    le.fit(list(set(all_activities)))

    for col in activity_cols:
        train_df[col] = train_df[col].fillna('missing')
        train_df[col] = le.transform(train_df[col])
        if test_df is not None:
            test_df[col] = test_df[col].fillna('missing')
            test_df[col] = le.transform(test_df[col])

    return train_df, test_df

def standardize(data, cols, train_data=None):
    """
    Estandariza las columnas especificadas.
    Usa las estadísticas del conjunto de entrenamiento si están disponibles.
    """
    if train_data is None:  # Si es el conjunto de entrenamiento
        media = data[cols].mean()
        stds = data[cols].std() # desviacion estandar

    else:  # Si es el conjunto de prueba
        media = train_data[cols].mean()
        stds = train_data[cols].std()

    datos_standarizados = (data[cols] - media) / stds
    return datos_standarizados  # Retorna un DataFrame con las mismas columnas

def normalize(data, columns):
    """
    Normaliza las columnas especificadas del DataFrame al rango [0, 1].

    :param data: DataFrame de pandas
    :param columns: Lista de nombres de columnas a normalizar
    :return: DataFrame con las columnas normalizadas
    """
    # Crea una copia del DataFrame para evitar modificar el original
    normalized_data = data.copy()

    # Itera a través de cada columna a normalizar
    for col in columns:
        col_min = data[col].min()  # Calcula el valor mínimo de la columna
        col_max = data[col].max()  # Calcula el valor máximo de la columna

        # Aplica la fórmula de normalización: (valor - min) / (max - min)
        normalized_data[col] = (data[col] - col_min) / (col_max - col_min)

    # Devuelve el DataFrame con las columnas normalizadas
    return normalized_data[columns] # Devuelve un subconjunto de columnas normalizadas

# %%
def prepare_data2(train_path, test_path=None, tipy=False,faltantes = False):
    train_df = pd.read_csv(train_path)
    test_df = pd.read_csv(test_path) if test_path else None   # cargar datos csv

    print("filas: " ,train_df.shape[0],"y colunmas: " ,train_df.shape[1])
    train_df = process_time(train_df)   #  agrega columnas como hora, minuto y segundo
    if test_df is not None:
        test_df = process_time(test_df)

    if faltantes == False:
        # identificar columnas tipos
        bg_cols = [col for col in train_df.columns if col.startswith('bg-')] # identifica en diferentes categorias
        insulin_cols = [col for col in train_df.columns if col.startswith('insulin-')]
        carbs_cols = [col for col in train_df.columns if col.startswith('carbs-')]
        hr_cols = [col for col in train_df.columns if col.startswith('hr-')]
        steps_cols = [col for col in train_df.columns if col.startswith('steps-')]
        cals_cols = [col for col in train_df.columns if col.startswith('cals-')]
        activity_cols = [col for col in train_df.columns if col.startswith('activity-')]

        print("manejo faltantes valores...")
        # manejo faltantes numericos valores
        numerical_cols = bg_cols + insulin_cols + carbs_cols + hr_cols + steps_cols + cals_cols
        print(numerical_cols)
        for col in numerical_cols:
            train_df[col] = train_df[col].fillna(train_df[col].mean())
            if test_df is not None:
                test_df[col] = test_df[col].fillna(train_df[col].mean())

        #Llena los valores faltantes en las columnas numéricas con la media de la columna correspondiente
        #en el conjunto de entrenamiento.


        print("Encoding actividades, one hot enconding pasar de cadenas a valores numericos")
        #train_df, test_df = encode_activities(train_df, test_df, activity_cols) # revisar la funcion encode
        train_df, test_df = encode_activities_manual(train_df, test_df, activity_cols) # revisar la funcion encode
        print()
        if tipy == False:
              print("estandarizando...")
              train_df[numerical_cols] = standardize(train_df, numerical_cols)
              if test_df is not None:
                test_df[numerical_cols] = standardize(test_df, numerical_cols, train_data=train_df)
        else:
              print("Normalizando...")
              train_df[numerical_cols] = normalize(train_df, numerical_cols)
              if test_df is not None:
                test_df[numerical_cols] = normalize(test_df, numerical_cols, train_data=train_df)

        #definir las columnas objetivo y caracteristicas
        feature_cols = (bg_cols + insulin_cols + carbs_cols + hr_cols + steps_cols +
                      cals_cols + activity_cols + ['hour', 'minute', 'second'])

        X_train = train_df[feature_cols].values
        y_train = train_df['bg+1:00'] #.values.reshape(-1, 1) # objetivo


        if test_df is not None:

            X_test = test_df[feature_cols].values

            print("asdasdasd",type(X_test))
            return X_train, y_train, X_test, feature_cols # mismas columnas que X_train.
        else:
            return X_train, y_train, None, feature_cols

    else:
              # identificar columnas tipos
        bg_cols = [col for col in train_df.columns if col.startswith('bg-')] # identifica en diferentes categorias
        insulin_cols = [col for col in train_df.columns if col.startswith('insulin-')]
        carbs_cols = [col for col in train_df.columns if col.startswith('carbs-')]
        #hr_cols = [col for col in train_df.columns if col.startswith('hr-')]
        #steps_cols = [col for col in train_df.columns if col.startswith('steps-')]
        #cals_cols = [col for col in train_df.columns if col.startswith('cals-')]
        #activity_cols = [col for col in train_df.columns if col.startswith('activity-')]

        print("manejo faltantes valores...")
        numerical_cols = bg_cols + insulin_cols + carbs_cols
        #print(numerical_cols)
        for group_name, group_cols in zip(
            ["bg", "insulin", "carbs"],
            [bg_cols, insulin_cols, carbs_cols]):
            print(f"Procesando grupo: {group_name}")

            for col in group_cols:
                train_df[col] = train_df.apply(
                    lambda row: row[col] if pd.notna(row[col]) else row[group_cols].mean(), axis=1)

            if test_df is not None:
                test_df[col] = test_df.apply(
                    lambda row: row[col] if pd.notna(row[col]) else row[group_cols].mean(), axis=1)

            #Llena los valores faltantes en las filas numéricas con la media de la fila  correspondiente
          # a la misma  variable


        if tipy == False:
              print("estandarizando...")
              train_df[numerical_cols] = standardize(train_df, numerical_cols)
              if test_df is not None:
                test_df[numerical_cols] = standardize(test_df, numerical_cols, train_data=train_df)
        else:
              print("Normalizando...")
              train_df[numerical_cols] = normalize(train_df, numerical_cols)
              if test_df is not None:
                test_df[numerical_cols] = normalize(test_df, numerical_cols, train_data=train_df)

        #definir las columnas objetivo y caracteristicas
        feature_cols = (bg_cols + insulin_cols + carbs_cols)

        X_train = train_df[feature_cols].values
        y_train = train_df['bg+1:00']


        if test_df is not None:

            X_test = test_df[feature_cols].values

            print("asdasdasd",type(X_test))
            return X_train, y_train, X_test, feature_cols # mismas columnas que X_train.
        else:
            return X_train, y_train, None, feature_cols

# %%
def prepare_test(train_path, tipy=False,faltantes = False):
    train_df = pd.read_csv(train_path)
    test_df = None

    print("filas: " ,train_df.shape[0],"y colunmas: " ,train_df.shape[1])
    train_df = process_time(train_df)   #  agrega columnas como hora, minuto y segundo
    """if test_df is not None:
        test_df = process_time(test_df)"""

    if faltantes == False:
        # identificar columnas tipos
        bg_cols = [col for col in train_df.columns if col.startswith('bg-')] # identifica en diferentes categorias
        insulin_cols = [col for col in train_df.columns if col.startswith('insulin-')]
        carbs_cols = [col for col in train_df.columns if col.startswith('carbs-')]
        hr_cols = [col for col in train_df.columns if col.startswith('hr-')]
        steps_cols = [col for col in train_df.columns if col.startswith('steps-')]
        cals_cols = [col for col in train_df.columns if col.startswith('cals-')]
        activity_cols = [col for col in train_df.columns if col.startswith('activity-')]

        print("manejo faltantes valores...")
        # manejo faltantes numericos valores
        numerical_cols = bg_cols + insulin_cols + carbs_cols + hr_cols + steps_cols + cals_cols
        print(numerical_cols)
        for col in numerical_cols:
            train_df[col] = train_df[col].fillna(train_df[col].mean())
            """ if test_df is not None:
                test_df[col] = test_df[col].fillna(train_df[col].mean())
            """
        #Llena los valores faltantes en las columnas numéricas con la media de la columna correspondiente
        #en el conjunto de entrenamiento.


        print("Encoding actividades, one hot enconding pasar de cadenas a valores numericos")
        #train_df, test_df = encode_activities(train_df, test_df, activity_cols) # revisar la funcion encode
        train_df, test_df = encode_activities_manual(train_df, test_df, activity_cols) # revisar la funcion encode
        print()
        if tipy == False:
              print("estandarizando...")
              train_df[numerical_cols] = standardize(train_df, numerical_cols)
              """if test_df is not None:
                test_df[numerical_cols] = standardize(test_df, numerical_cols, train_data=train_df)"""
        else:
              print("Normalizando...")
              train_df[numerical_cols] = normalize(train_df, numerical_cols)
              """if test_df is not None:
                test_df[numerical_cols] = normalize(test_df, numerical_cols, train_data=train_df)"""

        #definir las columnas objetivo y caracteristicas
        feature_cols = (bg_cols + insulin_cols + carbs_cols + hr_cols + steps_cols +
                      cals_cols + activity_cols + ['hour', 'minute', 'second'])

        X_train = train_df[feature_cols].values
        #y_train = train_df['bg+1:00'] #.values.reshape(-1, 1) # objetivo


        """if test_df is not None:

            X_test = test_df[feature_cols].values

            print("asdasdasd",type(X_test))
            return X_train, y_train, X_test, feature_cols # mismas columnas que X_train.
        else:
            return X_train, y_train, None, feature_cols"""
        return X_train

    else:
              # identificar columnas tipos
        bg_cols = [col for col in train_df.columns if col.startswith('bg-')] # identifica en diferentes categorias
        insulin_cols = [col for col in train_df.columns if col.startswith('insulin-')]
        carbs_cols = [col for col in train_df.columns if col.startswith('carbs-')]
        #hr_cols = [col for col in train_df.columns if col.startswith('hr-')]
        #steps_cols = [col for col in train_df.columns if col.startswith('steps-')]
        #cals_cols = [col for col in train_df.columns if col.startswith('cals-')]
        #activity_cols = [col for col in train_df.columns if col.startswith('activity-')]

        print("manejo faltantes valores...")
        numerical_cols = bg_cols + insulin_cols + carbs_cols
        #print(numerical_cols)
        for group_name, group_cols in zip(
            ["bg", "insulin", "carbs"],
            [bg_cols, insulin_cols, carbs_cols]):
            print(f"Procesando grupo: {group_name}")

            for col in group_cols:
                train_df[col] = train_df.apply(
                    lambda row: row[col] if pd.notna(row[col]) else row[group_cols].mean(), axis=1)

            """if test_df is not None:
                test_df[col] = test_df.apply(
                    lambda row: row[col] if pd.notna(row[col]) else row[group_cols].mean(), axis=1)"""

            #Llena los valores faltantes en las filas numéricas con la media de la fila  correspondiente
          # a la misma  variable


        if tipy == False:
              print("estandarizando...")
              train_df[numerical_cols] = standardize(train_df, numerical_cols)
              """if test_df is not None:
                test_df[numerical_cols] = standardize(test_df, numerical_cols, train_data=train_df)"""
        else:
              print("Normalizando...")
              train_df[numerical_cols] = normalize(train_df, numerical_cols)
              if test_df is not None:
                test_df[numerical_cols] = normalize(test_df, numerical_cols, train_data=train_df)

        #definir las columnas objetivo y caracteristicas
        feature_cols = (bg_cols + insulin_cols + carbs_cols)

        X_train = train_df[feature_cols].values
        #y_train = train_df['bg+1:00']


        """if test_df is not None:

            X_test = test_df[feature_cols].values

            print("asdasdasd",type(X_test))
            return X_train, y_train, X_test, feature_cols # mismas columnas que X_train.
        else:
            return X_train, y_train, None, feature_cols"""

        return X_train

# %% [markdown]
# # Datos crudos

# %%
data_p=pd.read_csv('train.csv')

pd.set_option('display.max_columns', None)
data_p.head()
# Out:
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  bg-5:20  bg-5:15  bg-5:10  bg-5:05  bg-5:00  bg-4:55  \
# 0      9.7      NaN      NaN      9.2      NaN      NaN      8.7      NaN
# 1      9.2      NaN      NaN      8.7      NaN      NaN      8.4      NaN
# 2      8.7      NaN      NaN      8.4      NaN      NaN      8.1      NaN
# 3      8.4      NaN      NaN      8.1      NaN      NaN      8.3      NaN
# 4      8.1      NaN      NaN      8.3      NaN      NaN      9.6      NaN
#
#    bg-4:50  bg-4:45  bg-4:40  bg-4:35  bg-4:30  bg-4:25  bg-4:20  bg-4:15  \
# 0      NaN      8.4      NaN      NaN      8.1      NaN      NaN      8.3
# 1      NaN      8.1      NaN      NaN      8.3      NaN      NaN      9.6
# 2      NaN      8.3      NaN      NaN      9.6      NaN      NaN     11.1
# 3      NaN      9.6      NaN      NaN     11.1      NaN      NaN     11.8
# 4      NaN     11.1      NaN      NaN     11.8      NaN      NaN     12.8
#
#    bg-4:10  bg-4:05  bg-4:00  bg-3:55  bg-3:50  bg-3:45  bg-3:40  bg-3:35  \
# 0      NaN      NaN      9.6      NaN      NaN     11.1      NaN      NaN
# 1      NaN      NaN     11.1      NaN      NaN     11.8      NaN      NaN
# 2      NaN      NaN     11.8      NaN      NaN     12.8      NaN      NaN
# 3      NaN      NaN     12.8      NaN      NaN     13.9      NaN      NaN
# 4      NaN      NaN     13.9      NaN      NaN     14.2      NaN      NaN
#
#    bg-3:30  bg-3:25  bg-3:20  bg-3:15  bg-3:10  bg-3:05  bg-3:00  bg-2:55  \
# 0     11.8      NaN      NaN     12.8      NaN      NaN     13.9      NaN
# 1     12.8      NaN      NaN     13.9      NaN      NaN     14.2      NaN
# 2     13.9      NaN      NaN     14.2      NaN      NaN     14.2      NaN
# 3     14.2      NaN      NaN     14.2      NaN      NaN     15.4      NaN
# 4     14.2      NaN      NaN     15.4      NaN      NaN     17.2      NaN
#
#    bg-2:50  bg-2:45  bg-2:40  bg-2:35  bg-2:30  bg-2:25  bg-2:20  bg-2:15  \
# 0      NaN     14.2      NaN      NaN     14.2      NaN      NaN     15.4
# 1      NaN     14.2      NaN      NaN     15.4      NaN      NaN     17.2
# 2      NaN     15.4      NaN      NaN     17.2      NaN      NaN     18.2
# 3      NaN     17.2      NaN      NaN     18.2      NaN      NaN     18.4
# 4      NaN     18.2      NaN      NaN     18.4      NaN      NaN     18.0
#
#    bg-2:10  bg-2:05  bg-2:00  bg-1:55  bg-1:50  bg-1:45  bg-1:40  bg-1:35  \
# 0      NaN      NaN     17.2      NaN      NaN     18.2      NaN      NaN
# 1      NaN      NaN     18.2      NaN      NaN     18.4      NaN      NaN
# 2      NaN      NaN     18.4      NaN      NaN     18.0      NaN      NaN
# 3      NaN      NaN     18.0      NaN      NaN     17.3      NaN      NaN
# 4      NaN      NaN     17.3      NaN      NaN     17.5      NaN      NaN
#
#    bg-1:30  bg-1:25  bg-1:20  bg-1:15  bg-1:10  bg-1:05  bg-1:00  bg-0:55  \
# 0     18.4      NaN      NaN     18.0      NaN      NaN     17.3      NaN
# 1     18.0      NaN      NaN     17.3      NaN      NaN     17.5      NaN
# 2     17.3      NaN      NaN     17.5      NaN      NaN     17.3      NaN
# 3     17.5      NaN      NaN     17.3      NaN      NaN     16.2      NaN
# 4     17.3      NaN      NaN     16.2      NaN      NaN     15.1      NaN
#
#    bg-0:50  bg-0:45  bg-0:40  bg-0:35  bg-0:30  bg-0:25  bg-0:20  bg-0:15  \
# 0      NaN     17.5      NaN      NaN     17.3      NaN      NaN     16.2
# 1      NaN     17.3      NaN      NaN     16.2      NaN      NaN     15.1
# 2      NaN     16.2      NaN      NaN     15.1      NaN      NaN     14.4
# 3      NaN     15.1      NaN      NaN     14.4      NaN      NaN     13.9
# 4      NaN     14.4      NaN      NaN     13.9      NaN      NaN     13.8
#
#    bg-0:10  bg-0:05  bg-0:00  insulin-5:55  insulin-5:50  insulin-5:45  \
# 0      NaN      NaN     15.1        0.0083        0.0083        0.0083
# 1      NaN      NaN     14.4        0.0083        0.0083        0.0083
# 2      NaN      NaN     13.9        0.0083        0.0083        0.0083
# 3      NaN      NaN     13.8        0.0083        0.0083        0.0083
# 4      NaN      NaN     13.4        0.0083        0.0083        0.0083
#
#    insulin-5:40  insulin-5:35  insulin-5:30  insulin-5:25  insulin-5:20  \
# 0        0.0083        0.0083        0.0083        0.0083        0.0083
# 1        0.0083        0.0083        0.0083        0.0083        0.0083
# 2        0.0083        0.0083        0.0083        0.0083        0.0083
# 3        0.0083        0.0083        0.0083        0.0083        0.0083
# 4        0.0083        0.0083        0.0083        0.0083        0.0083
#
#    insulin-5:15  insulin-5:10  insulin-5:05  insulin-5:00  insulin-4:55  \
# 0        0.0083        0.0083        0.0083        0.0083        0.0083
# 1        0.0083        0.0083        0.0083        0.0083        0.0083
\
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#    cals-2:50  cals-2:45  cals-2:40  cals-2:35  cals-2:30  cals-2:25  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#    cals-2:20  cals-2:15  cals-2:10  cals-2:05  cals-2:00  cals-1:55  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#    cals-1:50  cals-1:45  cals-1:40  cals-1:35  cals-1:30  cals-1:25  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#    cals-1:20  cals-1:15  cals-1:10  cals-1:05  cals-1:00  cals-0:55  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#    cals-0:50  cals-0:45  cals-0:40  cals-0:35  cals-0:30  cals-0:25  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#    cals-0:20  cals-0:15  cals-0:10  cals-0:05  cals-0:00 activity-5:55  \
# 0        NaN        NaN        NaN        NaN        NaN           NaN
# 1        NaN        NaN        NaN        NaN        NaN           NaN
# 2        NaN        NaN        NaN        NaN        NaN           NaN
# 3        NaN        NaN        NaN        NaN        NaN           NaN
# 4        NaN        NaN        NaN        NaN        NaN           NaN
#
#   activity-5:50 activity-5:45 activity-5:40 activity-5:35 activity-5:30  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-5:25 activity-5:20 activity-5:15 activity-5:10 activity-5:05  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-5:00 activity-4:55 activity-4:50 activity-4:45 activity-4:40  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-4:35 activity-4:30 activity-4:25 activity-4:20 activity-4:15  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-4:10 activity-4:05 activity-4:00 activity-3:55 activity-3:50  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-3:45 activity-3:40 activity-3:35 activity-3:30 activity-3:25  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-3:20 activity-3:15 activity-3:10 activity-3:05 activity-3:00  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-2:55 activity-2:50 activity-2:45 activity-2:40 activity-2:35  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-2:30 activity-2:25 activity-2:20 activity-2:15 activity-2:10  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-2:05 activity-2:00 activity-1:55 activity-1:50 activity-1:45  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-1:40 activity-1:35 activity-1:30 activity-1:25 activity-1:20  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-1:15 activity-1:10 activity-1:05 activity-1:00 activity-0:55  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-0:50 activity-0:45 activity-0:40 activity-0:35 activity-0:30  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-0:25 activity-0:20 activity-0:15 activity-0:10 activity-0:05  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-0:00  bg+1:00
# 0           NaN     13.4
# 1           NaN     12.8
# 2           NaN     15.5
# 3           NaN     14.8
# 4           NaN     12.7

# %%
data_p=pd.read_csv('test.csv')

pd.set_option('display.max_columns', None)
data_p.head()
# Out:
#          id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_8459   p01  06:45:00      NaN      9.2      NaN      NaN     10.2
# 1  p01_8460   p01  11:25:00      NaN      NaN      9.9      NaN      NaN
# 2  p01_8461   p01  14:45:00      NaN      5.5      NaN      NaN      5.5
# 3  p01_8462   p01  04:30:00      NaN      3.4      NaN      NaN      3.9
# 4  p01_8463   p01  04:20:00      NaN      NaN      8.3      NaN      NaN
#
#    bg-5:30  bg-5:25  bg-5:20  bg-5:15  bg-5:10  bg-5:05  bg-5:00  bg-4:55  \
# 0      NaN      NaN     10.3      NaN      NaN     10.2      NaN      NaN
# 1      9.4      NaN      NaN      9.1      NaN      NaN      8.3      NaN
# 2      NaN      NaN      5.2      NaN      NaN      5.2      NaN      NaN
# 3      NaN      NaN      4.7      NaN      NaN      4.1      NaN      NaN
# 4     10.0      NaN      NaN     12.2      NaN      NaN     12.8      NaN
#
#    bg-4:50  bg-4:45  bg-4:40  bg-4:35  bg-4:30  bg-4:25  bg-4:20  bg-4:15  \
# 0     11.7      NaN      NaN     13.5      NaN      NaN     15.3      NaN
# 1      NaN      7.7      NaN      NaN      7.8      NaN      NaN      7.7
# 2      NaN      5.1      NaN      NaN      5.1      NaN      NaN      4.7
# 3      3.5      NaN      NaN      3.9      NaN      NaN      4.3      NaN
# 4      NaN     12.8      NaN      NaN     12.2      NaN      NaN     11.4
#
#    bg-4:10  bg-4:05  bg-4:00  bg-3:55  bg-3:50  bg-3:45  bg-3:40  bg-3:35  \
# 0      NaN     15.0      NaN      NaN     14.4      NaN      NaN     13.6
# 1      NaN      NaN      7.1      NaN      NaN      7.1      NaN      NaN
# 2      NaN      NaN      4.4      NaN      NaN      4.8      NaN      NaN
# 3      NaN      4.6      NaN      NaN      3.8      NaN      NaN      3.1
# 4      NaN      NaN     12.1      NaN      NaN     11.8      NaN      NaN
#
#    bg-3:30  bg-3:25  bg-3:20  bg-3:15  bg-3:10  bg-3:05  bg-3:00  bg-2:55  \
# 0      NaN      NaN     12.6      NaN      NaN     11.9      NaN      NaN
# 1      6.7      NaN      NaN      6.6      NaN      NaN      6.9      NaN
# 2      6.1      NaN      NaN      6.9      NaN      NaN      6.3      NaN
# 3      NaN      NaN      3.6      NaN      NaN      4.2      NaN      NaN
# 4     10.7      NaN      NaN      9.6      NaN      NaN      8.9      NaN
#
#    bg-2:50  bg-2:45  bg-2:40  bg-2:35  bg-2:30  bg-2:25  bg-2:20  bg-2:15  \
# 0     11.4      NaN      NaN     11.9      NaN      NaN     12.9      NaN
# 1      NaN      8.6      NaN      NaN      9.7      NaN      NaN      9.1
# 2      NaN      5.2      NaN      NaN      4.7      NaN      NaN      5.1
# 3      4.2      NaN      NaN      4.1      NaN      NaN      4.2      NaN
# 4      NaN      8.4      NaN      NaN      7.3      NaN      NaN      5.8
#
#    bg-2:10  bg-2:05  bg-2:00  bg-1:55  bg-1:50  bg-1:45  bg-1:40  bg-1:35  \
# 0      NaN     13.8      NaN      NaN     13.7      NaN      NaN     13.9
# 1      NaN      NaN      7.7      NaN      NaN      6.1      NaN      NaN
# 2      NaN      NaN      5.1      NaN      NaN      5.2      NaN      NaN
# 3      NaN      3.9      NaN      NaN      NaN      3.3      NaN      NaN
# 4      NaN      NaN      4.3      NaN      NaN      3.4      NaN      NaN
#
#    bg-1:30  bg-1:25  bg-1:20  bg-1:15  bg-1:10  bg-1:05  bg-1:00  bg-0:55  \
# 0      NaN      NaN     14.6      NaN      NaN     14.1      NaN      NaN
# 1      5.0      NaN      NaN      4.4      NaN      NaN      3.9      NaN
# 2      5.3      NaN      NaN      4.7      NaN      NaN      4.9      NaN
# 3      3.7      NaN      NaN      5.1      NaN      NaN      6.4      NaN
# 4      3.1      NaN      NaN      2.9      NaN      NaN      3.3      NaN
#
#    bg-0:50  bg-0:45  bg-0:40  bg-0:35  bg-0:30  bg-0:25  bg-0:20  bg-0:15  \
\
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    carbs-5:20  carbs-5:15  carbs-5:10  carbs-5:05  carbs-5:00  carbs-4:55  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4        10.0         NaN         NaN         NaN         NaN         NaN
#
#    carbs-4:50  carbs-4:45  carbs-4:40  carbs-4:35  carbs-4:30  carbs-4:25  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    carbs-4:20  carbs-4:15  carbs-4:10  carbs-4:05  carbs-4:00  carbs-3:55  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN        30.0         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    carbs-3:50  carbs-3:45  carbs-3:40  carbs-3:35  carbs-3:30  carbs-3:25  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    carbs-3:20  carbs-3:15  carbs-3:10  carbs-3:05  carbs-3:00  carbs-2:55  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    carbs-2:50  carbs-2:45  carbs-2:40  carbs-2:35  carbs-2:30  carbs-2:25  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    carbs-2:20  carbs-2:15  carbs-2:10  carbs-2:05  carbs-2:00  carbs-1:55  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN        10.0         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    carbs-1:50  carbs-1:45  carbs-1:40  carbs-1:35  carbs-1:30  carbs-1:25  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    carbs-1:20  carbs-1:15  carbs-1:10  carbs-1:05  carbs-1:00  carbs-0:55  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    carbs-0:50  carbs-0:45  carbs-0:40  carbs-0:35  carbs-0:30  carbs-0:25  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    carbs-0:20  carbs-0:15  carbs-0:10  carbs-0:05  carbs-0:00  hr-5:55  \
# 0         NaN         NaN         NaN         NaN         NaN     59.7
# 1        20.0         NaN         NaN         NaN         NaN     58.1
# 2         NaN         NaN         NaN         NaN         NaN     62.4
# 3         NaN         NaN         NaN         NaN         NaN     67.6
# 4         NaN         NaN         NaN         NaN         NaN     73.8
#
#    hr-5:50  hr-5:45  hr-5:40  hr-5:35  hr-5:30  hr-5:25  hr-5:20  hr-5:15  \
# 0     55.6     58.2     59.3     58.0     62.7     59.7     55.7     55.8
# 1     59.1     63.4     59.8     60.5     58.6     60.5     57.8     56.1
# 2     62.3     61.6     65.1     58.7     59.5     59.7     59.4     60.2
# 3     69.3     66.7     69.1     70.2     71.0     68.1     86.2     86.4
# 4     70.4     68.6     67.2     75.7     74.4     88.3     68.3     68.9
#
#    hr-5:10  hr-5:05  hr-5:00  hr-4:55  hr-4:50  hr-4:45  hr-4:40  hr-4:35  \
# 0     57.2     61.1     57.9     58.2     58.5     58.1     58.2     56.9
# 1     57.9     54.9     54.8     57.3     56.0     54.4     54.8     59.3
# 2     65.5     65.9     65.9     62.1     67.3     66.4     67.7     65.6
# 3     88.7     72.0     70.2     66.5     71.0     68.5     66.6     72.3
# 4     67.2     65.6     69.1     72.3     68.3     66.0     63.1     71.5
#
#    hr-4:30  hr-4:25  hr-4:20  hr-4:15  hr-4:10  hr-4:05  hr-4:00  hr-3:55  \
# 0     58.4     61.3     69.7     51.8     52.6     53.4     54.9     55.3
# 1     56.0     58.0     56.9     56.7     58.7     60.5     54.1     54.8
# 2     68.6     64.4     64.5     65.9     81.2     83.4     74.3     69.2
# 3     72.4     67.6     66.7     70.4     72.7     71.4     71.8     71.6
# 4     83.4     86.0     78.4     69.9     67.1     61.2     59.8     55.6
#
         NaN         NaN         NaN         NaN         NaN
# 1         NaN         0.0         NaN         NaN         0.0         NaN
# 2         7.0         0.0         0.0         0.0         NaN         0.0
# 3       141.0        45.0        62.0         0.0        11.0         0.0
# 4         0.0         0.0         0.0        13.0         0.0         0.0
#
#    steps-4:50  steps-4:45  steps-4:40  steps-4:35  steps-4:30  steps-4:25  \
# 0         NaN         NaN         NaN         0.0         NaN        14.0
# 1         NaN         NaN         0.0         NaN         0.0         0.0
# 2         NaN        21.0         NaN         NaN         NaN         6.0
# 3         0.0         0.0         NaN         8.0         0.0         0.0
# 4         0.0        13.0        13.0        53.0        77.0        86.0
#
#    steps-4:20  steps-4:15  steps-4:10  steps-4:05  steps-4:00  steps-3:55  \
# 0        17.0         NaN         NaN         NaN         NaN         NaN
# 1         0.0         0.0         5.0        18.0         0.0         NaN
# 2         NaN        96.0        30.0        68.0         0.0         0.0
# 3         NaN         NaN         NaN         NaN         NaN         0.0
# 4        27.0        71.0         0.0         0.0         0.0         0.0
#
#    steps-3:50  steps-3:45  steps-3:40  steps-3:35  steps-3:30  steps-3:25  \
# 0         0.0         NaN         NaN         NaN         NaN         NaN
# 1         0.0         7.0         NaN         NaN         6.0         6.0
# 2         0.0         NaN         0.0        34.0        23.0         NaN
# 3         0.0         0.0         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    steps-3:20  steps-3:15  steps-3:10  steps-3:05  steps-3:00  steps-2:55  \
# 0         NaN         NaN         NaN         0.0         NaN         NaN
# 1        37.0         NaN         NaN         0.0        29.0        80.0
# 2         NaN         0.0        17.0        52.0        44.0       113.0
# 3         NaN         NaN         NaN         0.0         NaN         0.0
# 4         NaN         NaN         NaN         NaN         NaN         5.0
#
#    steps-2:50  steps-2:45  steps-2:40  steps-2:35  steps-2:30  steps-2:25  \
# 0         NaN         NaN         NaN         NaN         0.0         NaN
# 1       101.0       140.0       568.0       494.0       496.0        38.0
# 2        55.0        68.0       153.0         NaN        83.0        72.0
# 3         NaN         NaN         0.0         0.0         NaN         NaN
# 4         NaN         NaN         NaN         NaN         0.0         NaN
#
#    steps-2:20  steps-2:15  steps-2:10  steps-2:05  steps-2:00  steps-1:55  \
# 0         NaN         NaN         0.0         NaN         NaN         NaN
# 1        72.0        93.0        42.0        63.0        25.0        14.0
# 2        95.0       155.0       213.0       362.0       596.0       458.0
# 3         NaN         NaN         NaN         NaN         0.0         0.0
# 4         0.0         NaN         NaN         NaN         NaN         NaN
#
#    steps-1:50  steps-1:45  steps-1:40  steps-1:35  steps-1:30  steps-1:25  \
# 0         NaN         0.0         0.0         0.0         NaN         NaN
# 1        29.0        32.0        26.0        56.0        14.0        37.0
# 2       115.0        14.0        61.0       434.0       394.0         0.0
# 3         NaN         NaN         NaN         NaN         0.0         0.0
# 4         NaN         NaN         7.0         NaN         NaN         NaN
#
#    steps-1:20  steps-1:15  steps-1:10  steps-1:05  steps-1:00  steps-0:55  \
# 0         NaN         NaN         NaN         0.0         6.0         NaN
# 1        28.0        39.0        25.0         9.0        69.0        36.0
# 2        21.0        18.0         0.0         0.0        14.0        76.0
# 3         0.0         NaN         NaN         0.0         NaN         NaN
# 4         NaN         NaN         NaN         NaN         0.0         NaN
#
#    steps-0:50  steps-0:45  steps-0:40  steps-0:35  steps-0:30  steps-0:25  \
# 0         0.0         NaN         NaN         NaN         0.0         NaN
# 1         6.0        39.0         0.0        33.0       105.0       169.0
# 2       279.0       268.0       242.0       101.0       487.0        41.0
# 3         NaN         NaN         NaN         NaN         NaN         7.0
# 4         0.0        35.0         NaN         NaN         NaN         0.0
#
#    steps-0:20  steps-0:15  steps-0:10  steps-0:05  steps-0:00  cals-5:55  \
# 0         0.0         0.0         NaN         NaN         NaN       5.30
# 1       162.0       411.0       547.0       377.0       532.0       4.80
# 2        12.0        10.0        27.0       283.0        69.0       4.80
# 3         0.0        14.0         NaN         NaN         0.0       6.55
# 4         NaN         NaN         NaN         NaN         NaN       7.97
#
#    cals-5:50  cals-5:45  cals-5:40  cals-5:35  cals-5:30  cals-5:25  \
# 0        5.3       5.00       5.20       6.25       5.00       4.80
# 1        4.8       4.80       4.80       4.80       4.90       4.80
# 2        4.8       4.80       6.44       4.80       4.90       4.90
# 3        5.2       5.20       8.95      26.76      16.56      15.79
# 4        5.2       6.44       6.54       5.30      10.18      12.77
#
#    cals-5:20  cals-5:15  cals-5:10  cals-5:05  cals-5:00  cals-4:55  \
# 0       4.90       4.80       4.80       4.80       4.80        4.9
# 1       4.80       4.90       4.80       4.80       4.90        4.8
# 2       6.14       5.00       5.00       4.90       4.80        4.9
# 3       6.84       6.15       6.35       5.00       7.99        5.1
# 4       5.20       5.00       5.10       6.63       5.20        4.9
#
#    cals-4:50  cals-4:45  cals-4:40  cals-4:35  cals-4:30  cals-4:25  \
# 0        4.8       4.90       4.90       4.90       4.90       4.80
# 1        4.8       4.80       4.90       4.80       4.90       4.90
# 2        4.8       6.53       4.80       4.80       4.80       6.05
# 3        5.0       4.90       5.10       4.80       8.27      13.48
# 4        5.0       7.49       6.43      11.22      12.19      13.15
#
#    cals-4:20  cals-4:15  cals-4:10  cals-4:05  cals-4:00  cals-3:55  \
# 0       4.90       4.80       4.80       4.80       4.80        4.8
# 1       4.90       4.90       6.05       7.29       5.00        4.8
# 2       4.80      11.80       9.59      11.52       4.90        4.9
# 3      14.34      12.61      12.60       5.00       6.45        4.9
# 4       8.92      10.37       5.20       5.10       4.90        4.9
#
#    cals-3:50  cals-3:45  cals-3:40  cals-3:35  cals-3:30  cals-3:25  \
# 0        4.8       4.80        4.8       4.90       4.80       7.89
# 1        4.9       6.34        4.8       4.80       6.24       6.92
# 2        4.9       4.80        5.2       7.97       6.63       4.80
# 3        5.0       5.00        4.8       7.89       5.20       4.90
# 4        4.8       4.80        4.8       4.80       4.80       4.80
\
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-3:45 activity-3:40 activity-3:35 activity-3:30 activity-3:25  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-3:20 activity-3:15 activity-3:10 activity-3:05 activity-3:00  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-2:55 activity-2:50 activity-2:45 activity-2:40 activity-2:35  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-2:30 activity-2:25 activity-2:20 activity-2:15 activity-2:10  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-2:05 activity-2:00 activity-1:55 activity-1:50 activity-1:45  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-1:40 activity-1:35 activity-1:30 activity-1:25 activity-1:20  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-1:15 activity-1:10 activity-1:05 activity-1:00 activity-0:55  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-0:50 activity-0:45 activity-0:40 activity-0:35 activity-0:30  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-0:25 activity-0:20 activity-0:15 activity-0:10 activity-0:05  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN          Walk          Walk
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   activity-0:00
# 0           NaN
# 1          Walk
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3644 entries, 0 to 3643
# Columns: 507 entries, id to activity-0:00
# dtypes: float64(432), object(75)
# memory usage: 14.1+ MB

# %%
data_p['p_num'].unique() # 9 pacientes
# Out:
# array(['p01', 'p02', 'p04', 'p05', 'p06', 'p10', 'p11', 'p12', 'p15',
#        'p16', 'p18', 'p19', 'p21', 'p22', 'p24'], dtype=object)

# %%
data_p.isnull().sum().sum() # total de datos faltantes
# Out:
# 862409

# %%
#data_p['bg+1:00'].max() # valor maximo de glucosa

# %%
#data_p['bg+1:00'].min() # valor minimo de glucosa

# %% [markdown]
# # Cargar datos y procesamiento

# %%
# ruta del archivo
train_path = "train.csv"
test_ = "test.csv"
print(test_)
X_train, y_train, test_t, feature_cols = prepare_data2(train_path,test_,False,False)

print(f"Dimensiones de TEST: {test_t.shape}")
print()
print("Datos de entrenamiento preparados")
print()

print("ahora vamos separar dataset")
X_train_split, X_val, y_train_split, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)
print("dataset separado en entrenamiento y validación, su resultado es: ")
print()
# Verificar dimensiones después de la división
print(f"Dimensiones de X_train_split: {X_train_split.shape}, y_train_split: {y_train_split.shape}")
print()
print(f"Dimensiones de X_val: {X_val.shape}, y_val: {y_val.shape}")
# Out:
# test.csv
# filas:  177024 y colunmas:  508
# manejo faltantes valores...
# ['bg-5:55', 'bg-5:50', 'bg-5:45', 'bg-5:40', 'bg-5:35', 'bg-5:30', 'bg-5:25', 'bg-5:20', 'bg-5:15', 'bg-5:10', 'bg-5:05', 'bg-5:00', 'bg-4:55', 'bg-4:50', 'bg-4:45', 'bg-4:40', 'bg-4:35', 'bg-4:30', 'bg-4:25', 'bg-4:20', 'bg-4:15', 'bg-4:10', 'bg-4:05', 'bg-4:00', 'bg-3:55', 'bg-3:50', 'bg-3:45', 'bg-3:40', 'bg-3:35', 'bg-3:30', 'bg-3:25', 'bg-3:20', 'bg-3:15', 'bg-3:10', 'bg-3:05', 'bg-3:00', 'bg-2:55', 'bg-2:50', 'bg-2:45', 'bg-2:40', 'bg-2:35', 'bg-2:30', 'bg-2:25', 'bg-2:20', 'bg-2:15', 'bg-2:10', 'bg-2:05', 'bg-2:00', 'bg-1:55', 'bg-1:50', 'bg-1:45', 'bg
:50', 'carbs-0:45', 'carbs-0:40', 'carbs-0:35', 'carbs-0:30', 'carbs-0:25', 'carbs-0:20', 'carbs-0:15', 'carbs-0:10', 'carbs-0:05', 'carbs-0:00', 'hr-5:55', 'hr-5:50', 'hr-5:45', 'hr-5:40', 'hr-5:35', 'hr-5:30', 'hr-5:25', 'hr-5:20', 'hr-5:15', 'hr-5:10', 'hr-5:05', 'hr-5:00', 'hr-4:55', 'hr-4:50', 'hr-4:45', 'hr-4:40', 'hr-4:35', 'hr-4:30', 'hr-4:25', 'hr-4:20', 'hr-4:15', 'hr-4:10', 'hr-4:05', 'hr-4:00', 'hr-3:55', 'hr-3:50', 'hr-3:45', 'hr-3:40', 'hr-3:35', 'hr-3:30', 'hr-3:25', 'hr-3:20', 'hr-3:15', 'hr-3:10', 'hr-3:05', 'hr-3:00', 'hr-2:55', 'hr-2:50', 'hr-2:45', 'hr-2:40', 'hr-2:35', 'hr-2:30', 'hr-2:25', 'hr-2:20', 'hr-2:15', 'hr-2:10', 'hr-2:05', 'hr-2:00', 'hr-1:55', 'hr-1:50', 'hr-1:45', 'hr-1:40', 'hr-1:35', 'hr-1:30', 'hr-1:25', 'hr-1:20', 'hr-1:15', 'hr-1:10', 'hr-1:05', 'hr-1:00', 'hr-0:55', 'hr-0:50', 'hr-0:45', 'hr-0:40', 'hr-0:35', 'hr-0:30', 'hr-0:25', 'hr-0:20', 'hr-0:15', 'hr-0:10', 'hr-0:05', 'hr-0:00', 'steps-5:55', 'steps-5:50', 'steps-5:45', 'steps-5:40', 'steps-5:35', 'steps-5:30', 'steps-5:25', 'steps-5:20', 'steps-5:15', 'steps-5:10', 'steps-5:05', 'steps-5:00', 'steps-4:55', 'steps-4:50', 'steps-4:45', 'steps-4:40', 'steps-4:35', 'steps-4:30', 'st ...
# Encoding actividades, one hot enconding pasar de cadenas a valores numericos
# {'Aerobic Workout': 0, 'Bike': 1, 'CoreTraining': 2, 'Cycling': 3, 'Dancing': 4, 'HIIT': 5, 'Hike': 6, 'Indoor climbing': 7, 'Outdoor Bike': 8, 'Run': 9, 'Running': 10, 'Spinning': 11, 'Sport': 12, 'Stairclimber': 13, 'Strength training': 14, 'Swim': 15, 'Swimming': 16, 'Tennis': 17, 'Walk': 18, 'Walking': 19, 'Weights': 20, 'Workout': 21, 'Yoga': 22, 'Zumba': 23, 'missing': 24}
#
# estandarizando...
# asdasdasd <class 'numpy.ndarray'>
# Dimensiones de TEST: (3644, 507)
#
# Datos de entrenamiento preparados
#
# ahora vamos separar dataset
# dataset separado en entrenamiento y validación, su resultado es:
#
# Dimensiones de X_train_split: (141619, 507), y_train_split: (141619,)
#
# Dimensiones de X_val: (35405, 507), y_val: (35405,)

# %%
pd.DataFrame(X_train, columns=feature_cols).head() # ---hipoglusemia
# Out:
#    bg-5:55  bg-5:50   bg-5:45  bg-5:40  bg-5:35   bg-5:30  bg-5:25  bg-5:20  \
# 0      0.0      0.0  0.475926      0.0      0.0  0.509995      0.0      0.0
#    activity-2:00  activity-1:55  activity-1:50  activity-1:45  activity-1:40  \
# 0           24.0           24.0           24.0           24.0           24.0
# 1           24.0           24.0           24.0           24.0           24.0
# 2           24.0           24.0           24.0           24.0           24.0
# 3           24.0           24.0           24.0           24.0           24.0
# 4           24.0           24.0           24.0           24.0           24.0
#
#    activity-1:35  activity-1:30  activity-1:25  activity-1:20  activity-1:15  \
# 0           24.0           24.0           24.0           24.0           24.0
# 1           24.0           24.0           24.0           24.0           24.0
# 2           24.0           24.0           24.0           24.0           24.0
# 3           24.0           24.0           24.0           24.0           24.0
# 4           24.0           24.0           24.0           24.0           24.0
#
#    activity-1:10  activity-1:05  activity-1:00  activity-0:55  activity-0:50  \
# 0           24.0           24.0           24.0           24.0           24.0
# 1           24.0           24.0           24.0           24.0           24.0
# 2           24.0           24.0           24.0           24.0           24.0
# 3           24.0           24.0           24.0           24.0           24.0
# 4           24.0           24.0           24.0           24.0           24.0
#
#    activity-0:45  activity-0:40  activity-0:35  activity-0:30  activity-0:25  \
# 0           24.0           24.0           24.0           24.0           24.0
# 1           24.0           24.0           24.0           24.0           24.0
# 2           24.0           24.0           24.0           24.0           24.0
# 3           24.0           24.0           24.0           24.0           24.0
# 4           24.0           24.0           24.0           24.0           24.0
#
#    activity-0:20  activity-0:15  activity-0:10  activity-0:05  activity-0:00  \
# 0           24.0           24.0           24.0           24.0           24.0
# 1           24.0           24.0           18.0           18.0           18.0
# 2           24.0           24.0           24.0           24.0           24.0
# 3           24.0           24.0           24.0           24.0           24.0
# 4           24.0           24.0           24.0           24.0           24.0
#
#    hour  minute  second
# 0   6.0    45.0     0.0
# 1  11.0    25.0     0.0
# 2  14.0    45.0     0.0
# 3   4.0    30.0     0.0
# 4   4.0    20.0     0.0

# %%
test_t_df = pd.DataFrame(X_train, columns=feature_cols)
print("tienes tantos ceros: ",test_t_df.isnull().sum().sum())
# Out:
# tienes tantos ceros:  0

# %% [markdown]
# #1. Linear Regression

# %%
print("Entrenando con regresión lineal...")
model = LinearRegression()
model.fit(X_train, y_train)
print(model)
# Out:
# Entrenando con regresión lineal...
# LinearRegression()

# %%
# Predicción y evaluación
"""
if X_val is not None:
    print("Prediciendo valores...")
    y_pred = model.predict(X_train)
    y_pred_test = model.predict(X_val)
    print(y_pred.T)
"""
if test_t is not None:
    print("Prediciendo valores...")
    y_pred = model.predict(test_t)
    y_pred_test = model.predict(X_val)
    print(y_pred.T)

maeL,mapeL, mseL,rmseL, r2L, evrL = Error(y_train, y_pred)
maeLT,mapeLT, mseLT,rmseLT, r2LT, evrLT = Error(y_val, y_pred_test)

print(f"Erros in train:")
print(f" MAE:{maeL:.4f}\n MAPE:{mapeL:.4f}\n MSE: {mseL:.4f}\n RMSE: {rmseL:.4f}\n R^2:{r2L:.4f}\n EVR:{evrL:.4f} ")
print("-----------------------")

print(f"Error in validation:")
print(f" MAE:{maeLT:.4f}\n MAPE:{mapeLT:.4f}\n MSE: {mseLT:.4f}\n RMSE: {rmseLT:.4f}\n R^2:{r2LT:.4f}\n EVR:{evrLT:.4f} ")
print("-----------------------")

# Gráfica de Predicción vs. Valor Real   lineal
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_pred, alpha=0.5, color='blue',label="Train")
plt.scatter(y_val, y_pred_test, alpha=0.5, color='green', label="Validacion")
plt.plot([min(y_val), max(y_val)], [min(y_val), max(y_val)], '--', color='red',label = "Identity")
plt.xlabel("Valores Reales")
plt.ylabel("Valores Predichos")
plt.title("Predicciones vs. Valores Reales (MODELO REGRESION LINEAL)")
plt.legend()
plt.show()

# %% [markdown]
# # 2. Árbol de decisión

# %%
print("Entrenando con Árbol de Decisión...")
model_AR = DecisionTreeRegressor(max_depth=10, min_samples_split=10, min_samples_leaf=10)
model_AR.fit(X_train, y_train)

# %%
if X_val is not None:
    print("Prediciendo valores...")
    y_pred4 = model_AR.predict(X_train)
    y_pred_test4 = model_AR.predict(X_val)


maeAR,mapeAR, mseAR,rmseAR, r2AR, evrAR = Error(y_train, y_pred4)
maeART,mapeART, mseART,rmseART, r2ART, evrART = Error(y_val, y_pred_test4)

print(f"Errores in train:")
print(f" MAE:{maeAR:.4f}\n MAPE:{mapeAR:.4f}\n MSE: {mseAR:.4f}\n RMSE: {rmseAR:.4f}\n R^2:{r2AR:.4f}\n EVR:{evrAR:.4f} ")
print("-----------------------")

print(f"Errores in validation:")
print(f" MAE:{maeART:.4f}\n MAPE:{mapeART:.4f}\n MSE: {mseART:.4f}\n RMSE: {rmseART:.4f}\n R^2:{r2ART:.4f}\n EVR:{evrART:.4f} ")
print("-----------------------")

# Gráfica de Predicción vs. Valor Real
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_pred4, alpha=0.5, color='blue' , label =" train")
plt.scatter(y_val, y_pred_test4, alpha=0.5, color='green', label =" validation")
plt.plot([min(y_val), max(y_val)], [min(y_val), max(y_val)], '--', color='red',label = "Identity")
plt.xlabel("Valores Reales")
plt.ylabel("Valores Predichos")
plt.title("Predicciones vs. Valores Reales (MODELO Árbol de decisión)")
plt.legend()
plt.show()

# %% [markdown]
# # 3. Random Forest

# %%
# Random Forest
import time
print("entrenando con bosque aleatorio")

model_RF = RandomForestRegressor(n_estimators=10)
inicio = time.time()
model_RF.fit(X_train, y_train)
fin = time.time()
T_total = (fin - inicio)/60
print(f"Tiempo de entrenamiento: {fin - inicio} segundos")
print(f"Tiempo de entrenamiento: {T_total} minutos")
# Out:
# entrenando con bosque aleatorio
# Tiempo de entrenamiento: 783.5066905021667 segundos
# Tiempo de entrenamiento: 13.058444841702778 minutos

# %%
# Predicción y evaluación
if X_val is not None:
    print("Prediciendo valores...")
    y_pred1 = model_RF.predict(X_train)
    y_pred_test1 = model_RF.predict(X_val)
    y_pred_test2 = model_RF.predict(test_t)

maeRF,mapeRF, mseRF,rmseRF, r2RF, evrRF = Error(y_train, y_pred1)
maeRFT,mapeRFT, mseRFT,rmseRFT, r2RFT, evrRFT = Error(y_val, y_pred_test1)
print(f"Erros in train:")
print(f" MAE:{maeRF:.4f}\n MAPE:{mapeRF:.4f}\n MSE: {mseRF:.4f}\n RMSE: {rmseRF:.4f}\n R^2:{r2RF:.4f}\n EVR:{evrRF:.4f} ")
print("-----------------------")

print(f"Error in validation:")
print(f" MAE:{maeRFT:.4f}\n MAPE:{mapeRFT:.4f}\n MSE: {mseRFT:.4f}\n RMSE: {rmseRFT:.4f}\n R^2:{r2RFT:.4f}\n EVR:{evrRFT:.4f} ")
print("-----------------------")


# Gráfica de Predicción vs. Valor Real   Randon Forest
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_pred1, alpha=0.5, color='blue',label = "train")
plt.scatter(y_val, y_pred_test1, alpha=0.5, color='green',label = "validation")
plt.plot([min(y_val), max(y_val)], [min(y_val), max(y_val)], '--', color='red',label = "Identity")

plt.xlabel("Valores Reales")
plt.ylabel("Valores Predichos")
plt.title("Predicciones vs. Valores Reales (Random Forest)")
plt.legend()
plt.show()
# Out:
# Prediciendo valores...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-aa9aa4fc6012> in <cell line: 10>()
#       8 maeRF,mapeRF, mseRF,rmseRF, r2RF, evrRF = Error(y_train, y_pred1)
#       9 maeRFT,mapeRFT, mseRFT,rmseRFT, r2RFT, evrRFT = Error(y_val, y_pred_test1)
# ---> 10 maeRFTT,mapeRFTT, mseRFTT,rmseRFTT, r2RFTT, evrRFTT = Error(y_val, y_pred_test2)
#      11 print(f"Erros in train:")
#      12 print(f" MAE:{maeRF:.4f}\n MAPE:{mapeRF:.4f}\n MSE: {mseRF:.4f}\n RMSE: {rmseRF:.4f}\n R^2:{r2RF:.4f}\n EVR:{evrRF:.4f} ")
#
# <ipython-input-3-af590db48647> in Error(y_real, y_pred)
#      17     # Validación de dimensiones
#      18     if y_real.shape != y_pred.shape:
# ---> 19         raise ValueError("Las dimensiones de y_real y y_pred no coinciden.")
#      20
#      21     # MAE (Error absoluto medio)
#
# ValueError: Las dimensiones de y_real y y_pred no coinciden.

# %% [markdown]
# #4. XGBoost

# %%
# Crear el modelo XGBoost
model_XGB = xgb.XGBRegressor(
    objective='reg:squarederror',  # Para regresión
    n_estimators=10,  # Número de árboles si aumenta este aumenta el entrenamiento pero es mejor
    max_depth=15,       # Profundidad máxima de cada árbol
    learning_rate=0.5, # Tasa de aprendizaje ,
    random_state=42
)
inicio = time.time()
# Entrenar el modelo
model_XGB.fit(X_train, y_train)
fin = time.time()
T_total = (fin - inicio)/60
print(f"Tiempo de entrenamiento: {fin - inicio} segundos")
print(f"Tiempo de entrenamiento: {T_total} minutos")

# %%
# Predicción y evaluación
if X_val is not None:
    print("Prediciendo valores...")
    y_pred2 = model_XGB.predict(X_train)
    y_pred_test2 = model_XGB.predict(X_val)

maeXGB,mapeXGB, mseXGB,rmseXGB, r2XGB, evrXGB = Error(y_train, y_pred2)
maeXGBT,mapeXGBT, mseXGBT,rmseXGBT, r2XGBT, evrXGBT = Error(y_val, y_pred_test2)

print(f"Erros in train:")
print(f" MAE:{maeXGB:.4f}\n MAPE:{mapeXGB:.4f}\n MSE: {mseXGB:.4f}\n RMSE: {rmseXGB:.4f}\n R^2:{r2XGB:.4f}\n EVR:{evrXGB:.4f} ")
print("-----------------------")

print(f"Error in validation:")
print(f" MAE:{maeXGBT:.4f}\n MAPE:{mapeXGBT:.4f}\n MSE: {mseXGBT:.4f}\n RMSE: {rmseXGBT:.4f}\n R^2:{r2XGBT:.4f}\n EVR:{evrXGBT:.4f} ")
print("-----------------------")

# Gráfica de Predicción vs. Valor Real   Randon Forest
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_pred2, alpha=0.5, color='blue', label = "Train")
plt.scatter(y_val, y_pred_test2, alpha=0.5, color='green',label = "Validation")
plt.plot([min(y_val), max(y_val)], [min(y_val), max(y_val)], '--', color='red',label = "Identity")
plt.legend()
plt.xlabel("Valores Reales")
plt.ylabel("Valores Predichos")
plt.title("Predicciones vs. Valores Reales (XGBoost)")
plt.show()

# %% [markdown]
# # 5. Red Neuronal

# %%
# !pip install pytorch-tabnet

# %%
# RED NEURONAL
from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
#  Modelo TabNet
model_RN = TabNetRegressor(verbose=1)

y_train_ = y_train.values.reshape(-1, 1) # Reshape to 2D for TabNetRegressor
y_val_ = y_val.values.reshape(-1, 1)
# Entrenar modelo
model_RN.fit(
    X_train, y_train_,  # Datos de entrenamiento
    eval_set=[(X_val, y_val_)],    # Datos de validación
    eval_metric=['rmse'],         # Métrica de evaluación
    max_epochs=5,               # Máximas épocas de entrenamiento
    patience=10,                  # Parada temprana si no mejora
    batch_size=1024,              # Tamaño del lote
)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# Predicción y evaluación
if X_val is not None:
    print("Prediciendo valores...")
    y_pred3 = model_RN.predict(X_train)
    y_pred_test3 = model_RN.predict(X_val)
    print(y_pred3.shape)
    print(y_pred_test3.shape)

maeRN,mapeRN, mseRN,rmseRN, r2RN, evrRN = Error(y_train_, y_pred3)
maeRNT,mapeRNT, mseRNT,rmseRNT, r2XRNT, evrRNT = Error(y_val_, y_pred_test3)

print(f"Erros in train:")
print(f" MAE:{maeRN:.4f}\n MAPE:{mapeRN:.4f}\n MSE: {mseRN:.4f}\n RMSE:{rmseRN:.4f}\n R^2:{r2RN:.4f}\n EVR:{evrRN:.4f} ")
print("-----------------------")

print(f"Error in validation:")
print(f" MAE:{maeRNT:.4f}\n MAPE:{mapeRNT:.4f}\n MSE: {mseRNT:.4f}\n RMSE:{rmseRNT:.4f}\n R^2:{r2XRNT:.4f}\n EVR:{evrRNT:.4f} ")
print("-----------------------")

# Gráfica de Predicción vs. Valor Real   Randon Forest
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_pred3, alpha=0.5, color='blue',label = "train")
plt.scatter(y_val, y_pred_test3, alpha=0.5, color='green',label = "Validation")
plt.plot([min(y_val), max(y_val)], [min(y_val), max(y_val)], '--', color='red',label="Identity")
plt.plot(y_val,y_val, alpha = 0.5, color = 'red')
plt.xlabel("Valores Reales")
plt.ylabel("Valores Predichos")
plt.title("Predicciones vs. Valores Reales (TabNetRegressor)")
plt.legend()
plt.show()
